# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('zomato.csv')

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
for i in df[df['rate']=='NEW']:
    df.update(df['rate'].replace('NEW',np.nan))

# %%
df.rate.unique()
# Out:
# array(['4.1/5', '3.8/5', '3.7/5', '3.6/5', '4.6/5', '4.0/5', '4.2/5',
#        '3.9/5', '3.1/5', '3.0/5', '3.2/5', '3.3/5', '2.8/5', '4.4/5',
#        '4.3/5', 'NEW', '2.9/5', '3.5/5', nan, '2.6/5', '3.8 /5', '3.4/5',
#        '4.5/5', '2.5/5', '2.7/5', '4.7/5', '2.4/5', '2.2/5', '2.3/5',
#        '3.4 /5', '-', '3.6 /5', '4.8/5', '3.9 /5', '4.2 /5', '4.0 /5',
#        '4.1 /5', '3.7 /5', '3.1 /5', '2.9 /5', '3.3 /5', '2.8 /5',
#        '3.5 /5', '2.7 /5', '2.5 /5', '3.2 /5', '2.6 /5', '4.5 /5',
#        '4.3 /5', '4.4 /5', '4.9/5', '2.1/5', '2.0/5', '1.8/5', '4.6 /5',
#        '4.9 /5', '3.0 /5', '4.8 /5', '2.3 /5', '4.7 /5', '2.4 /5',
#        '2.1 /5', '2.2 /5', '2.0 /5', '1.8 /5'], dtype=object)

# %%
df['rate']=df.rate.str.replace('/','')

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.isnull().sum()/100
# Out:
# url                              0.00
# address                          0.00
# name                             0.00
# online_order                     0.00
# book_table                       0.00
# rate                            77.75
# votes                            0.00
# phone                           12.08
# location                         0.21
# rest_type                        2.27
# dish_liked                     280.78
# cuisines                         0.45
# approx_cost(for two people)      3.46
# reviews_list                     0.00
# menu_item                        0.00
# listed_in(type)                  0.00
# listed_in(city)                  0.00
# dtype: float64

# %%
df['name']=df['name'].apply(lambda x:  '  '.join(x.split()[:3]))

# %%
df.isnull().sum()/len(df)*100
# Out:
# url                             0.000000
# address                         0.000000
# name                            0.000000
# online_order                    0.000000
# book_table                      0.000000
# rate                           15.033741
# votes                           0.000000
# phone                           2.335789
# location                        0.040606
# rest_type                       0.438927
# dish_liked                     54.291626
# cuisines                        0.087012
# approx_cost(for two people)     0.669026
# reviews_list                    0.000000
# menu_item                       0.000000
# listed_in(type)                 0.000000
# listed_in(city)                 0.000000
# dtype: float64

# %%
df['rate'].unique()
# Out:
# array(['4.15', '3.85', '3.75', '3.65', '4.65', '4.05', '4.25', '3.95',
#        '3.15', '3.05', '3.25', '3.35', '2.85', '4.45', '4.35', 'NEW',
#        '2.95', '3.55', nan, '2.65', '3.8 5', '3.45', '4.55', '2.55',
#        '2.75', '4.75', '2.45', '2.25', '2.35', '3.4 5', '-', '3.6 5',
#        '4.85', '3.9 5', '4.2 5', '4.0 5', '4.1 5', '3.7 5', '3.1 5',
#        '2.9 5', '3.3 5', '2.8 5', '3.5 5', '2.7 5', '2.5 5', '3.2 5',
#        '2.6 5', '4.5 5', '4.3 5', '4.4 5', '4.95', '2.15', '2.05', '1.85',
#        '4.6 5', '4.9 5', '3.0 5', '4.8 5', '2.3 5', '4.7 5', '2.4 5',
#        '2.1 5', '2.2 5', '2.0 5', '1.8 5'], dtype=object)

# %%
df['rate']=df['rate'].replace(['NEW', '-'], np.nan)

# %%
df['rate']=df['rate'].str.replace(' ','').astype(float)

# %%
df['rate'].fillna(df['rate'].mean(),inplace=True)

# %%
df.head(50)
# Out:
#                                                   url  \
# 0   https://www.zomato.com/bangalore/jalsa-banasha...
# 1   https://www.zomato.com/bangalore/spice-elephan...
# 2   https://www.zomato.com/SanchurroBangalore?cont...
# 3   https://www.zomato.com/bangalore/addhuri-udupi...
# 4   https://www.zomato.com/bangalore/grand-village...
# 5   https://www.zomato.com/bangalore/timepass-dinn...
# 6   https://www.zomato.com/bangalore/rosewood-inte...
# 7   https://www.zomato.com/bangalore/onesta-banash...
# 8   https://www.zomato.com/bangalore/penthouse-caf...
# 9   https://www.zomato.com/bangalore/smacznego-ban...
# 10  https://www.zomato.com/bangalore/caf%C3%A9-dow...
# 11  https://www.zomato.com/bangalore/cafe-shuffle-...
# 12  https://www.zomato.com/bangalore/the-coffee-sh...
# 13  https://www.zomato.com/bangalore/caf-eleven-ba...
# 14  https://www.zomato.com/SanchurroBangalore?cont...
# 15  https://www.zomato.com/bangalore/cafe-vivacity...
# ...

# %%
df.phone.value_counts()
# Out:
# phone
# 080 43334321                          216
# 080 43334333                          167
# +91 7005889963                         78
# +91 8197170008                         75
# +91 7710055553                         58
#                                      ...
# +91 9845687999\r\r\n080 41494199        1
# +91 9606443393\r\r\n+91 9606443394      1
# +91 9538798222                          1
# 080 48902064\r\r\n+91 9620723546        1
# +91 8884297989\r\r\n+91 9886759367      1
# Name: count, Length: 14926, dtype: int64

# %%
df['phone'].str.replace(' ','')
# Out:
# 0          08042297555\r\n+919743772233
# 1                           08041714161
# 2                         +919663487993
# 3                         +919620009302
# 4        +918026612447\r\n+919901210005
#                       ...
# 51712                       08040301477
# 51713                     +918197675843
# 51714                               NaN
# 51715                       08049652769
# 51716                     +918071117272
# Name: phone, Length: 51717, dtype: object

# %%
df['phone'].str.replace('.','')
# Out:
# 0          080 42297555\r\n+91 9743772233
# 1                            080 41714161
# 2                          +91 9663487993
# 3                          +91 9620009302
# 4        +91 8026612447\r\n+91 9901210005
#                        ...
# 51712                        080 40301477
# 51713                      +91 8197675843
# 51714                                 NaN
# 51715                        080 49652769
# 51716                      +91 8071117272
# Name: phone, Length: 51717, dtype: object

# %%
import re

# %%
def clean_phone_number(phone):
    if isinstance(phone,str):
        primary_number= re.split(r'[\\.]', phone)[0]
        return primary_number.split()
    return phone

# %%
df['phone']=df['phone'].apply(clean_phone_number)

# %%
df.head(20)
# Out:
#                                                   url  \
# 0   https://www.zomato.com/bangalore/jalsa-banasha...
# 1   https://www.zomato.com/bangalore/spice-elephan...
# 2   https://www.zomato.com/SanchurroBangalore?cont...
# 3   https://www.zomato.com/bangalore/addhuri-udupi...
# 4   https://www.zomato.com/bangalore/grand-village...
# 5   https://www.zomato.com/bangalore/timepass-dinn...
# 6   https://www.zomato.com/bangalore/rosewood-inte...
# 7   https://www.zomato.com/bangalore/onesta-banash...
# 8   https://www.zomato.com/bangalore/penthouse-caf...
# 9   https://www.zomato.com/bangalore/smacznego-ban...
# 10  https://www.zomato.com/bangalore/caf%C3%A9-dow...
# 11  https://www.zomato.com/bangalore/cafe-shuffle-...
# 12  https://www.zomato.com/bangalore/the-coffee-sh...
# 13  https://www.zomato.com/bangalore/caf-eleven-ba...
# 14  https://www.zomato.com/SanchurroBangalore?cont...
# 15  https://www.zomato.com/bangalore/cafe-vivacity...
# ...

# %%
#df['phone'].unique()

# %%
#df['phone'].str.replace(np.nan,'missing')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         51717 non-null  float64
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
df.head(2)
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
#
#                                              address             name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...            Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...  Spice  Elephant
#
#   online_order book_table  rate  votes                             phone  \
# 0          Yes        Yes  4.15    775  [080, 42297555, +91, 9743772233]
# 1          Yes         No  4.15    787                   [080, 41714161]
#
#        location      rest_type  \
# 0  Banashankari  Casual Dining
# 1  Banashankari  Casual Dining
#
#                                           dish_liked  \
# 0  Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1  Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
#
#                          cuisines approx_cost(for two people)  \
# ...

# %%
df['location']=df['location'].fillna(df['location'].mode()[0])

# %%
df.isnull().sum()/len(df)*100
# Out:
# url                             0.000000
# address                         0.000000
# name                            0.000000
# online_order                    0.000000
# book_table                      0.000000
# rate                            0.000000
# votes                           0.000000
# phone                           2.335789
# location                        0.000000
# rest_type                       0.438927
# dish_liked                     54.291626
# cuisines                        0.087012
# approx_cost(for two people)     0.669026
# reviews_list                    0.000000
# menu_item                       0.000000
# listed_in(type)                 0.000000
# listed_in(city)                 0.000000
# dtype: float64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.drop(columns='dish_liked',inplace=True)

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                     name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                    Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...          Spice  Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San  Churro  Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri  Udupi  Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...           Grand  Village
#
#   online_order book_table  rate  votes                               phone  \
# 0          Yes        Yes  4.15    775    [080, 42297555, +91, 9743772233]
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
#s=pd.Series(df['phone'])
#s.apply(lambda x: s.replace('[]',''))

# %%
df['rest_type'].fillna(df['rest_type'].mode()[0],inplace=True)

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                     name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                    Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...          Spice  Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San  Churro  Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri  Udupi  Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...           Grand  Village
#
#   online_order book_table  rate  votes                               phone  \
# 0          Yes        Yes  4.15    775    [080, 42297555, +91, 9743772233]
# ...

# %%
x=df['phone']

# %%
d=pd.DataFrame(x)

# %%
 replacement_value =df['phone'].iloc[::]

# %%
df['phone'].fillna(replacement_value)
# Out:
# 0          [080, 42297555, +91, 9743772233]
# 1                           [080, 41714161]
# 2                         [+91, 9663487993]
# 3                         [+91, 9620009302]
# 4        [+91, 8026612447, +91, 9901210005]
#                         ...
# 51712                       [080, 40301477]
# 51713                     [+91, 8197675843]
# 51714                                   NaN
# 51715                       [080, 49652769]
# 51716                     [+91, 8071117272]
# Name: phone, Length: 51717, dtype: object

# %%
df['phone'].isna().sum()
# Out:
# 1208

# %%
phone=df['phone'].apply(lambda x: x[-1] if isinstance(x,list) else x)

# %%
df['phone']=phone.fillna(00000000000)

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df['approx_cost(for two people)'].isnull().sum()
# Out:
# 346

# %%
df['approx_cost(for two people)'].unique()
# Out:
# array(['800', '300', '600', '700', '550', '500', '450', '650', '400',
#        '900', '200', '750', '150', '850', '100', '1,200', '350', '250',
#        '950', '1,000', '1,500', '1,300', '199', '80', '1,100', '160',
#        '1,600', '230', '130', '50', '190', '1,700', nan, '1,400', '180',
#        '1,350', '2,200', '2,000', '1,800', '1,900', '330', '2,500',
#        '2,100', '3,000', '2,800', '3,400', '40', '1,250', '3,500',
#        '4,000', '2,400', '2,600', '120', '1,450', '469', '70', '3,200',
#        '60', '560', '240', '360', '6,000', '1,050', '2,300', '4,100',
#        '5,000', '3,700', '1,650', '2,700', '4,500', '140'], dtype=object)

# %%
#df['approx_cost(for two people)'].apply(lambda x: df['approx_cost(for two people)'].replace(' ,  ',''))

# %%
#df['approx_cost(for two people)'].str.replace(', ','.' , regex=False)

# %%
arr=np.array(df['approx_cost(for two people)'])

# %%
df1= pd.Series(arr)

# %%
df2 = df1.str.replace(',', '', regex=False)

# %%
df['approx_cost(for two people)']=pd.DataFrame(df2)

# %%
df['approx_cost(for two people)']=df['approx_cost(for two people)'].fillna(df['approx_cost(for two people)'].median()).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         51717 non-null  float64
#  6   votes                        51717 non-null  int64
#  7   phone                        51717 non-null  object
#  8   location                     51717 non-null  object
#  9   rest_type                    51717 non-null  object
#  10  cuisines                     51672 non-null  object
#  11  approx_cost(for two people)  51717 non-null  int32
#  12  reviews_list                 51717 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# url                             0
# address                         0
# name                            0
# online_order                    0
# book_table                      0
# rate                            0
# votes                           0
# phone                           0
# location                        0
# rest_type                       0
# cuisines                       45
# approx_cost(for two people)     0
# reviews_list                    0
# menu_item                       0
# listed_in(type)                 0
# listed_in(city)                 0
# dtype: int64

# %%
df['cuisines']=df['cuisines'].fillna(df['cuisines'].mode()[0])

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.to_csv("zomato_clear.csv")
